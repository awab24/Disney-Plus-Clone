# %% [markdown]
# <a href="https://colab.research.google.com/github/awab24/Disney-Plus-Clone/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('content.drive')

# %%
import tensorflow as tf
import cv2
import numpy as np
import matplotlib.pyplot as plt
#from PIL import Images

# %%
#load and preprocess
image = cv2.imread('/content/images.jpg', cv2.IMREAD_GRAYSCALE)

# %%
#define a kernel
kernel = np.array([[1, 1,1], [1,1,1],[1,1,1]], dtype = np.float32)

# %%
#Apply convultion using openCV (equivelant to linear filter)
convolved = cv2.filter2D(image, -1, kernel)

# %%
#plot original and filtered images
plt.figure(figsize = (10, 5))
plt.subplot(1,2,1)
plt.title("original Image")
plt.imshow(image, cmap = 'gray')
plt.axis('on')

plt.subplot(1,2,2)
plt.title("filtered (convultion)")
plt.imshow(image, cmap='gray')
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(224.5), np.float64(224.5), np.float64(-0.5))
